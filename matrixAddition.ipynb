# %% [markdown]
# <a href="https://colab.research.google.com/github/thrishul26/CUDA-Labs/blob/main/matrixAddition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# ...
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-ju8vceu8
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-ju8vceu8
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit 5741c522547756ac4bb7a16df32106a15efb8a57
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for nvcc4jupyter: filename=nvcc4jupyter-1.2.1-py3-none-any.whl size=10741 sha256=1c43b610d84440f376c57bb0b3d20f87e2433fdb6f06eb98d5fd7c81c461a971
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ohf3cq4q/wheels/a8/b9/18/23f8ef71ceb0f63297dd1903aedd067e6243a68ea756d6feea
# Successfully built nvcc4jupyter
# ...

# %%
pip install nvcc4jupyter

# %%
# %load_ext nvcc4jupyter
# Out:
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpi6hpgprp".

# %%
# %%cuda
#
# #include <assert.h>
# #include <cuda.h>
# #include <stdio.h>
# #include <stdlib.h>
# #include <stddef.h>
# #define N 100 // Size of the matrices (N x N)
#
# __global__ void matrixAdd(int *a, int *b, int *c) {
#     int row = blockIdx.y * blockDim.y + threadIdx.y;
#     int col = blockIdx.x * blockDim.x + threadIdx.x;
#     int index = row * N + col;
#
#     if (row < N && col < N) {
#         c[index] = a[index] + b[index];
#     }
# }
#
# int main() {
#     int a[N][N], b[N][N], c[N][N];
#     int *dev_a, *dev_b, *dev_c;
#     int size = N * N * sizeof(int);
#
#     // Initialize matrices a and b with some values
#     for (int i = 0; i < N; ++i) {
#         for (int j = 0; j < N; ++j) {
#             a[i][j] = 7;
#             b[i][j] = 1;
#         }
#     }
#
#
#     cudaMalloc((void **)&dev_a, size);
#     cudaMalloc((void **)&dev_b, size);
#     cudaMalloc((void **)&dev_c, size);
#
#     cudaMemcpy(dev_a, a, size, cudaMemcpyHostToDevice);
#     cudaMemcpy(dev_b, b, size, cudaMemcpyHostToDevice);
#
#
#     dim3 threadsPerBlock(16, 16);
#     dim3 numBlocks((N + threadsPerBlock.x - 1) / threadsPerBlock.x, (N + threadsPerBlock.y - 1) / threadsPerBlock.y);
#
#     matrixAdd<<<numBlocks, threadsPerBlock>>>(dev_a, dev_b, dev_c);
#
#     cudaMemcpy(c, dev_c, size, cudaMemcpyDeviceToHost);
#
#     printf("Result Matrix:\n");
#     for (int i = 0; i < N; ++i) {
#         for (int j = 0; j < N; ++j) {
#             printf("%d ", c[i][j]);
#         }
#         printf("\n");
#     }
#
#     cudaFree(dev_a);
#     cudaFree(dev_b);
#     cudaFree(dev_c);
#
#     return 0;
# }
# Out:
# Result Matrix:
# 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
# 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
# 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
# 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
# ...
